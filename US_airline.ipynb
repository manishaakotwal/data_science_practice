# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('US Airline.csv')
# Out:
# /tmp/ipykernel_3649/272044896.py:1: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('US Airline.csv')

# %%
df = data.copy()

# %%
# statistics of data
df.info() ,df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245955 entries, 0 to 245954
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tbl             245955 non-null  object
#  1   Year            245955 non-null  int64
#  2   quarter         245955 non-null  int64
#  3   citymarketid_1  245955 non-null  int64
#  4   citymarketid_2  245955 non-null  int64
#  5   city1           245955 non-null  object
#  6   city2           245955 non-null  object
#  7   airportid_1     245955 non-null  int64
#  8   airportid_2     245955 non-null  int64
#  9   airport_1       245955 non-null  object
#  10  airport_2       245955 non-null  object
#  11  nsmiles         245955 non-null  int64
#  12  passengers      245955 non-null  int64
#  13  fare            245955 non-null  float64
#  14  carrier_lg      244415 non-null  object
#  15  large_ms        244415 non-null  float64
# ...

# %%
# checking data types
df.columns
# Out:
# Index(['tbl', 'Year', 'quarter', 'citymarketid_1', 'citymarketid_2', 'city1',
#        'city2', 'airportid_1', 'airportid_2', 'airport_1', 'airport_2',
#        'nsmiles', 'passengers', 'fare', 'carrier_lg', 'large_ms', 'fare_lg',
#        'carrier_low', 'lf_ms', 'fare_low', 'Geocoded_City1', 'Geocoded_City2',
#        'tbl1apk'],
#       dtype='object')

# %%
data_types = df.dtypes
data_types
# Out:
# tbl                object
# Year                int64
# quarter             int64
# citymarketid_1      int64
# citymarketid_2      int64
# city1              object
# city2              object
# airportid_1         int64
# airportid_2         int64
# airport_1          object
# airport_2          object
# nsmiles             int64
# passengers          int64
# fare              float64
# carrier_lg         object
# large_ms          float64
# fare_lg           float64
# carrier_low        object
# lf_ms             float64
# fare_low          float64
# Geocoded_City1     object
# Geocoded_City2     object
# tbl1apk            object
# dtype: object

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# shape of data
df.shape
# Out:
# (245955, 23)

# %%
df.size
# Out:
# 5656965

# %%
df.head(5) # top 5 rows of the dataframe
# Out:
#        tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table1a  2021        3           30135           33195
# 1  Table1a  2021        3           30135           33195
# 2  Table1a  2021        3           30140           30194
# 3  Table1a  2021        3           30140           30194
# 4  Table1a  2021        3           30140           30466
#
#                             city1                          city2  airportid_1  \
# 0  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 1  Allentown/Bethlehem/Easton, PA  Tampa, FL (Metropolitan Area)        10135
# 2                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# 3                 Albuquerque, NM          Dallas/Fort Worth, TX        10140
# 4                 Albuquerque, NM                    Phoenix, AZ        10140
#
#    airportid_2 airport_1  ...    fare  carrier_lg  large_ms  fare_lg  \
# 0        14112       ABE  ...   81.43          G4    1.0000    81.43
# ...

# %%
df.sample(5) # for generate random rows from the dataframe
# Out:
#              tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 121069  Table 1a  2014        1           32575           33044
# 28454   Table 1a  2005        2           32575           33244
# 164221  Table 1a  2007        4           30194           33256
# 61705   Table 1a  2006        1           30792           32467
# 173271  Table 1a  2010        3           32575           32467
#
#                                       city1                          city2  \
# 121069  Los Angeles, CA (Metropolitan Area)                 Louisville, KY
# 28454   Los Angeles, CA (Metropolitan Area)                    Memphis, TN
# 164221                Dallas/Fort Worth, TX   Mission/McAllen/Edinburg, TX
# 61705                           Buffalo, NY  Miami, FL (Metropolitan Area)
# 173271  Los Angeles, CA (Metropolitan Area)  Miami, FL (Metropolitan Area)
#
#         airportid_1  airportid_2 airport_1  ...    fare  carrier_lg  large_ms  \
# ...

# %%
# check null values
df.isna().sum()
# Out:
# tbl                   0
# Year                  0
# quarter               0
# citymarketid_1        0
# citymarketid_2        0
# city1                 0
# city2                 0
# airportid_1           0
# airportid_2           0
# airport_1             0
# airport_2             0
# nsmiles               0
# passengers            0
# fare                  0
# carrier_lg         1540
# large_ms           1540
# fare_lg            1540
# carrier_low        1612
# lf_ms              1612
# fare_low           1612
# Geocoded_City1    39206
# Geocoded_City2    39206
# tbl1apk               0
# dtype: int64

# %%
# visualize missing data
import matplotlib.pyplot as plt
import seaborn as sns

# visualize missing data by heatmap
sns.heatmap(df.isna(), cbar=False)
plt.show()

# %%
# dropping rows and columns with any missing values
# df_cleaned = df.dropna()
df.dropna(inplace = True)

# df_cleaned_columns = df.dropna(axis=1)

# print(df_cleaned.shape)
# print(df_cleaned_columns.shape)

# %%
df.shape
# Out:
# (205189, 23)

# %%
df.index
# Out:
# Index([  5919,   5920,   5921,   5922,   5923,   5924,   5925,   5926,   5927,
#          5928,
#        ...
#        222933, 222934, 222935, 222936, 222937, 222938, 222939, 222940, 222941,
#        222942],
#       dtype='int64', length=205189)

# %%
# data cleaning

for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        plt.figure(figsize=(10, 4))
        sns.boxplot(x=df[column])
        plt.title(f'Box Plot for {column}')
        plt.show()

# %%
for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        print(f"Column: {column}")
        print(df[column].describe())
# Out:
# Column: Year
# count    205189.000000
# mean       2006.203344
# std           7.357540
# min        1993.000000
# 25%        2000.000000
# 50%        2006.000000
# 75%        2012.000000
# max        2020.000000
# Name: Year, dtype: float64
# Column: quarter
# count    205189.000000
# mean          2.453821
# std           1.114433
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max           4.000000
# Name: quarter, dtype: float64
# Column: citymarketid_1
# count    205189.000000
# mean      31557.506255
# std        1087.876837
# min       30135.000000
# 25%       30721.000000
# 50%       31423.000000
# 75%       32467.000000
# max       35412.000000
# Name: citymarketid_1, dtype: float64
# Column: citymarketid_2
# count    205189.000000
# mean      32179.255686
# std        1230.573397
# min       30189.000000
# 25%       31057.000000
# 50%       32211.000000
# 75%       33192.000000
# max       35412.000000
# ...

# %%
# outliers detect in - citymarketid_1,passengers, fare,fare_lg, fare_low 
Features_with_outliers=['citymarketid_1', 'passengers', 'fare', 'fare_lg','fare_low']

# %%
# remove outliers by IQR (inter - quartile range)
def remove_outliers(out):
    # calculate IQ1 AND IQ3
    q1 = np.percentile(out, 25)
    q3 = np.percentile(out, 75)

    # calculate IQR Range
    iqr = q3 -q1
    # define lower and upper bounds of outliers
    lower_bound = q1 - 1.5* iqr
    upper_bound = q3 + 1.5* iqr
    lower_bound ,upper_bound
    #remove outliers
    out= np.where(out>upper_bound, upper_bound, np.where(out<lower_bound, lower_bound, out))
    return out[(out >= lower_bound) & (out <= upper_bound)]

# %%
for column in Features_with_outliers:
    df[column] = remove_outliers(df[column])

# %%
# outliers check
int_vars = df.select_dtypes(include = ['int','float'])

# Determine the number of subplots needed
num_vars = len(int_vars.columns)
nrows = (num_vars + 2) // 3

fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(15,10))
axs = axs.flatten()

for i, var in enumerate (int_vars):
    sns.boxplot(x=var,data=df,ax=axs[i])
    axs[i].set_title(var)

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205189 entries, 5919 to 222942
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tbl             205189 non-null  object
#  1   Year            205189 non-null  int64
#  2   quarter         205189 non-null  int64
#  3   citymarketid_1  205189 non-null  float64
#  4   citymarketid_2  205189 non-null  int64
#  5   city1           205189 non-null  object
#  6   city2           205189 non-null  object
#  7   airportid_1     205189 non-null  int64
#  8   airportid_2     205189 non-null  int64
#  9   airport_1       205189 non-null  object
#  10  airport_2       205189 non-null  object
#  11  nsmiles         205189 non-null  int64
#  12  passengers      205189 non-null  float64
#  13  fare            205189 non-null  float64
#  14  carrier_lg      205189 non-null  object
#  15  large_ms        205189 non-null  float64
# ...

# %%
# analysis using plots
# How are the fare and nsmiles distributed?
# kde plots

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))
sns.histplot(df['fare'], kde=True, ax=axs[0])
axs[0].set_title('Distribution of Fare')

sns.histplot(df['nsmiles'], kde=True, ax=axs[1])
axs[1].set_title('Distribution of NS Miles')

plt.tight_layout()
plt.show()

# %%
#  Relationship Between Numerical Features
# What is the relationship between fare and passengers?
plt.figure(figsize=(15,10))
sns.scatterplot(x='fare', y='passengers', data=df)
plt.title('Fare vs. Passengers')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.pairplot(df[['fare', 'large_ms', 'fare_lg']])
plt.show()

# %%
# What is the average fare by year?
sns.lineplot(x='Year', y='fare', data=df.groupby('Year')['fare'].mean().reset_index(),marker ='o')
plt.title('Average Fare by Year')
plt.xlabel('Year')
plt.ylabel('Average Fare')
plt.show()

# %%
# How does the passenger count vary across different city1?
plt.figure(figsize=(12, 8))
top_cities = df.groupby('city1')['passengers'].sum().nlargest(10).reset_index()
sns.barplot(x='passengers', y='city1', data=top_cities)
plt.title('Top 10 Cities by Passenger Count')
plt.xlabel('Total Passengers')
plt.ylabel('City 1')
plt.show()

# %%
# Group by airport_1 and airport_2 separately and sum passengers

airport1_passengers = df.groupby('airport_1')['passengers'].sum().reset_index()
airport2_passengers = df.groupby('airport_2')['passengers'].sum().reset_index()

# Concatenate the results
busiest_airports = pd.concat([airport1_passengers, airport2_passengers], ignore_index=True)
busiest_airports = busiest_airports.groupby('airport_1')['passengers'].sum().reset_index()

# Top 10 busiest airports
top_airports = busiest_airports.nlargest(10, 'passengers')

plt.figure(figsize=(12, 8))
sns.barplot(x='passengers', y='airport_1', data=top_airports)
plt.title('Top 10 Busiest Airports by Passenger Count')
plt.xlabel('Total Passengers')
plt.ylabel('Airport')
plt.show()

# %%
df.head()
# Out:
#            tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 5919  Table 1a  2010        1         34614.0           33195
# 5920  Table 1a  1998        4         30189.0           31703
# 5921  Table 1a  1998        4         30198.0           30852
# 5922  Table 1a  2009        3         32211.0           32575
# 5923  Table 1a  1993        4         30255.0           30852
#
#                      city1                                  city2  \
# 5919    Salt Lake City, UT          Tampa, FL (Metropolitan Area)
# 5920  Colorado Springs, CO  New York City, NY (Metropolitan Area)
# 5921        Pittsburgh, PA     Washington, DC (Metropolitan Area)
# 5922         Las Vegas, NV    Los Angeles, CA (Metropolitan Area)
# 5923        Huntsville, AL     Washington, DC (Metropolitan Area)
#
#       airportid_1  airportid_2 airport_1  ...    fare  carrier_lg  large_ms  \
# 5919        14869        15304       SLC  ...  226.59          DL      0.38
# ...

# %%
# group by
grouped_data = df.groupby(['city1','city2'])['quarter'].count().reset_index()
grouped_data
# Out:
#                                    city1                                city2  \
# 0                             Albany, NY                          Chicago, IL
# 1                             Albany, NY                          Detroit, MI
# 2                             Albany, NY                       Fort Myers, FL
# 3                             Albany, NY                        Las Vegas, NV
# 4                             Albany, NY  Los Angeles, CA (Metropolitan Area)
# ...                                  ...                                  ...
# 1203                          Tucson, AZ   Washington, DC (Metropolitan Area)
# 1204                           Tulsa, OK   Washington, DC (Metropolitan Area)
# 1205                      Valparaiso, FL   Washington, DC (Metropolitan Area)
# 1206  Washington, DC (Metropolitan Area)       West Palm Beach/Palm Beach, FL
# 1207  Washington, DC (Metropolitan Area)                          Wichita, KS
#
#       quarter
# 0         202
# ...

# %% [markdown]
# ## connect with mysql

# %%
import sqlite3
from sqlalchemy import create_engine
import mysql.connector

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245955 entries, 0 to 245954
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tbl             245955 non-null  object
#  1   Year            245955 non-null  int64
#  2   quarter         245955 non-null  int64
#  3   citymarketid_1  245955 non-null  int64
#  4   citymarketid_2  245955 non-null  int64
#  5   city1           245955 non-null  object
#  6   city2           245955 non-null  object
#  7   airportid_1     245955 non-null  int64
#  8   airportid_2     245955 non-null  int64
#  9   airport_1       245955 non-null  object
#  10  airport_2       245955 non-null  object
#  11  nsmiles         245955 non-null  int64
#  12  passengers      245955 non-null  int64
#  13  fare            245955 non-null  float64
#  14  carrier_lg      244415 non-null  object
#  15  large_ms        244415 non-null  float64
# ...

# %%
database_uri = f'mysql+mysqlconnector://root:root@localhost:3306/us_airline'

# %%
engine = create_engine(database_uri)

# %%
df.reset_index()
# Out:
#          index       tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0         5919  Table 1a  2010        1         34614.0           33195
# 1         5920  Table 1a  1998        4         30189.0           31703
# 2         5921  Table 1a  1998        4         30198.0           30852
# 3         5922  Table 1a  2009        3         32211.0           32575
# 4         5923  Table 1a  1993        4         30255.0           30852
# ...        ...       ...   ...      ...             ...             ...
# 205184  222938   Table1a  2020        2         35086.0           33195
# 205185  222939   Table1a  2020        2         31834.0           32575
# 205186  222940   Table1a  2020        2         31834.0           32575
# 205187  222941   Table1a  2020        2         31834.0           32575
# 205188  222942   Table1a  2020        2         31834.0           32575
#
#                        city1                                  city2  \
# ...

# %%
# data entries insertion
# df.to_sql(name ='us_airline', con= engine, if_exists='append', index=False)
try:
    df.to_sql(name='flight_data', con=engine, if_exists='append', index=False)
    print("Data inserted successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data inserted successfully.

# %%
query ='select * from flight_data limit 5'
data = pd.read_sql(query,engine)
data
# Out:
#         tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0  Table 1a  2010        1           34614           33195
# 1  Table 1a  1998        4           30189           31703
# 2  Table 1a  1998        4           30198           30852
# 3  Table 1a  2009        3           32211           32575
# 4  Table 1a  1993        4           30255           30852
#
#                   city1                                  city2  airportid_1  \
# 0    Salt Lake City, UT          Tampa, FL (Metropolitan Area)        14869
# 1  Colorado Springs, CO  New York City, NY (Metropolitan Area)        11109
# 2        Pittsburgh, PA     Washington, DC (Metropolitan Area)        14122
# 3         Las Vegas, NV    Los Angeles, CA (Metropolitan Area)        12889
# 4        Huntsville, AL     Washington, DC (Metropolitan Area)        12217
#
#    airportid_2 airport_1  ...    fare  carrier_lg  large_ms  fare_lg  \
# 0        15304       SLC  ...  226.59          DL      0.38   247.69
# ...
